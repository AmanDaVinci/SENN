# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %cd ..
# Out:
# /home/vanio/Documents/NLCourses/FACT/FACT

# %%
from models.conceptizer import *
from utils.plot_utils import plot_lambda_accuracy

# %%
plot_lambda_accuracy(["compas_config.json"])
# Out:
# ...
#  EXPERIMENT: test
# ...
# {'aggregator': 'SumAggregator',
#  'batch_size': 200,
#  'checkpoint_dir': './saved_checkpoints/',
#  'checkpoint_file': 'compass.cpt',
#  'concept_reg': 0,
#  'conceptizer': 'IdentityConceptizer',
#  'dataloader': 'compas',
#  'device': 'cpu',
#  'dropout': 0.5,
#  'epochs': 30,
#  'eval_freq': 30,
#  'exp_name': 'test',
#  'experiment_dir': 'compas_lambda0_1',
#  'hidden_sizes': [11, 5, 5, 11],
#  'load_checkpoint': 'best_model.pt',
#  'lr': 0.01,
#  'num_classes': 1,
#  'num_concepts': 11,
#  'parameterizer': 'CompasParameterizer',
#  'print_freq': 100,
#  'robust_reg': 0,
#  'sparsity_reg': 0.001,
#  'train': True}
# SENN(
#   (conceptizer): IdentityConceptizer(
#     (encoder): ModuleList()
#     (decoder): ModuleList()
#   )
#   (parameterizer): CompasParameterizer(
#     (layers): Sequential(
#       (0): Linear(in_features=11, out_features=5, bias=True)
#       (1): Dropout(p=0.5, inplace=False)
#       (2): ReLU()
# ...

# %%
from trainer import init_trainer

# %%
trainer = init_trainer("config/compas_config.json", best_model=True)
# Out:
# ...
#  EXPERIMENT: test
# ...
# {'aggregator': 'SumAggregator',
#  'batch_size': 200,
#  'checkpoint_dir': './saved_checkpoints/',
#  'checkpoint_file': 'compass.cpt',
#  'concept_reg': 0,
#  'conceptizer': 'IdentityConceptizer',
#  'dataloader': 'compas',
#  'device': 'cpu',
#  'dropout': 0.5,
#  'epochs': 30,
#  'eval_freq': 30,
#  'exp_name': 'test',
#  'experiment_dir': 'compas_lambda0_1',
#  'hidden_sizes': [11, 5, 5, 11],
#  'load_checkpoint': 'best_model.pt',
#  'lr': 0.01,
#  'num_classes': 1,
#  'num_concepts': 11,
#  'parameterizer': 'CompasParameterizer',
#  'print_freq': 100,
#  'robust_reg': 0,
#  'sparsity_reg': 0.001,
#  'train': True}
# SENN(
#   (conceptizer): IdentityConceptizer(
#     (encoder): ModuleList()
#     (decoder): ModuleList()
#   )
#   (parameterizer): CompasParameterizer(
#     (layers): Sequential(
#       (0): Linear(in_features=11, out_features=5, bias=True)
#       (1): Dropout(p=0.5, inplace=False)
#       (2): ReLU()
# ...

# %%
trainer.test()
# Out:
# -------- Test --------
# Total Loss:0.505 	Classification Loss:0.505 	Robustness Loss:0.000 	Concept Loss:0.461 	Accuracy:0.615
# ----------------------------
# 0.6149999976158143
